# %% [markdown]
# # Batch vs Online vs Offline Mechine Learning

# %% [markdown]
# ## Batch Learning
#
# ```text
#  _______           _________________              _________________
# |       |         |                 |            |                 |
# |  Data |-------->|   Model Train   | ---------> |   Deploy Model  |
# |_______|         |_________________|            |_________________|
#                           |                               |
#                           |                               |
#                           |                               |
#                           |                               |
#                      _____|_____                     _____|_______
#                     |           |                   |             |
#                     | Re-Train  |<------------------|  New Data   |
#                     |___________|                   |_____________|
# ```

# %% [markdown]
# ## Online Learning
# ```text
#  _______           ___________              ____________               _________
# |       |         |           |            |            |             |         |
# |  Data |-------->|   Model   | ---------> |    Test    |-----------> |  Server |
# |_______|         |___________|            |____________|             |_________|
# ```

# %% [markdown]
# - in online learning some improve the model from new data.
# - Model(new) = Model(old) + New data

# %% [markdown]
# ```text
#  ___________           _______________              ____________
# |           |         |               |            |            |
# | New Data  |-------->| Traing Model  | ---------> |    Learn   |
# |___________|         |_______________|            |____________|
# ```

# %% [markdown]
# ## Offline Learning
# ```text
#  _______           ___________              ____________               ________________
# |       |         |           |            |            |             |                |
# |  Data |-------->|   Model   | ---------> | Save Model |-----------> |  Use the Model |
# |_______|         |___________|            |____________|             |      for       |
#                                                                       |  Production    |
#                                                                       |________________|
# ```

# %% [markdown]
# ---
# ---

# %% [markdown]
# - when dataset into 50 GB but ram 8GB,  then datast break into small group. then it work.
#
#
# ```text
# |                                                                                 |   * * *        |  * * * *
# |                                                                                 |  * * *         |   * * *
# |             * * * * * * * *  * * * * * *                                        |__________      |__________
# |            * * * * * * * * * *  * * * * * *
# |              * *  * * * * * * * * * * * * * * *
# |          * * * * * * * * * * * * * * * * * *  *                                 |   * *          |  * * **
# |            * * * * * * ** ** * * * * * * * *  *                   Break         |    * * *       |   * * *
# |             * * *  * * * * * * * * * * *  * *                     Dataset       |__________      |___________
# |            * * * * * * * * * * * *  * * *  *
# |             * * * * * * * * * * * *  * * * * *
# |           * *  * * * * * * * * * * * * ** *                                     |    * * *         |  * * * *
# |               * * * * * * * * * * * * * *                                       |  * * * * *       | * * * * *
# |             * * * * * * * * * * * * * * *  *                                    |   * * * *        |  * * * *
# |               * * * * * *  * * * * ** * * *                                     |______________    |____________
# |                   * * * * * * * * * * * *
# |
# |____________________________________________________________
#
# ```

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Instance Based  vs Model Based Learning
# ```text
# Learning
# |
# |
# |---> Momorizing
# |
# |---> Genaralizeing
#
# ```

# %% [markdown]
# ### Instance Based Learning
# ``` text
# |
# |--> Model Provide the similar answer of the previous answer
# ```

# %% [markdown]
# ```text                                           CGPA
# | iq | Cgpa | Placement |                          |
# |    |      |     y/n   |                          |   * * * * *     + + + +
# |    |      |           |                          |    * * * * *   + + + + +
# |----|------|-----------|                          |    * ** * *        + + + + ++
# | 80 |   8  |    y      |                          |   * * * * *  * * +   + + + + +
# |----|------|-----------|                          |    * * * *  * + * +*  + + + + +
# | 70 |   7  |    n      |                          |     * * * *   * * *    + + +  +
# |----|------|-----------|                          |         * * * * * * *  + + + +
# | 103| 7.5  |           |                          |____________________________IQ
#
#                                                                KNN
# ```

# %% [markdown]
# ### Mdoel Based Learning
# ``` text
# |
# |--> Model learn in data, and predicting the answer
# ```

# %%
```text                                           CGPA
| iq | Cgpa | Placement |                          |
|    |      |     y/n   |                          |   * * * * * +   + + + +
|    |      |           |                          |    * * * * * +   + + + + +
|----|------|-----------|                          |    * ** * * + *    * + * + + ++ 
| 80 |   8  |    y      |                          |   * * * * * * * +   + + + + +
|----|------|-----------|                          |    * * * * * + *   + * + + + + +
| 70 |   7  |    n      |                          |     * * * * * *   * + + +  + 
|----|------|-----------|                          |         * * * *   * * *  + + + + 
| 103| 7.5  |           |                          |____________________________________IQ
```
