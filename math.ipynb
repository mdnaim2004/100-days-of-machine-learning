# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('organizations-100.csv')
df.head()
# Out:
#    Index  Organization Id                     Name  \
# 0      1  FAB0d41d5b5d22c              Ferrell LLC
# 1      2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2      3  0bFED1ADAE4bcC1               Hester Ltd
# 3      4  2bFC1Be8a4ce42f           Holder-Sellers
# 4      5  9eE8A6a4Eb96C24              Mayer Group
#
#                           Website           Country  \
# 0              https://price.net/  Papua New Guinea
# 1  http://www.hall-buchanan.info/           Finland
# 2       http://sullivan-reed.com/             China
# 3             https://becker.com/      Turkmenistan
# 4          http://www.brewer.com/         Mauritius
#
#                                       Description  Founded  \
# 0             Horizontal empowering knowledgebase     1990
# 1             User-centric system-worthy leverage     2015
# 2                  Switchable scalable moratorium     1971
# 3  De-engineered systemic artificial intelligence     2004
# ...

# %%
df.shape
# Out:
# (100, 9)

# %%
df.sample()
# Out:
#    Index  Organization Id         Name                 Website    Country  \
# 4      5  9eE8A6a4Eb96C24  Mayer Group  http://www.brewer.com/  Mauritius
#
#                           Description  Founded        Industry  \
# 4  Synchronized needs-based challenge     1991  Transportation
#
#    Number of employees
# 4                 7870

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Index                100 non-null    int64
#  1   Organization Id      100 non-null    str
#  2   Name                 100 non-null    str
#  3   Website              100 non-null    str
#  4   Country              100 non-null    str
#  5   Description          100 non-null    str
#  6   Founded              100 non-null    int64
#  7   Industry             100 non-null    str
#  8   Number of employees  100 non-null    int64
# dtypes: int64(3), str(6)
# memory usage: 7.2 KB

# %%
df.isnull().sum()
# Out:
# Index                  0
# Organization Id        0
# Name                   0
# Website                0
# Country                0
# Description            0
# Founded                0
# Industry               0
# Number of employees    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %%
df.corr(numeric_only=True)
# Out:
#                         Index   Founded  Number of employees
# Index                1.000000 -0.195922            -0.155571
# Founded             -0.195922  1.000000             0.084122
# Number of employees -0.155571  0.084122             1.000000

# %%
df.corr(numeric_only=True)['Number of employees']
# Out:
# Index                 -0.155571
# Founded                0.084122
# Number of employees    1.000000
# Name: Number of employees, dtype: float64

# %%
import seaborn as sns

# %%
sns.countplot(df['Country'])
# Out:
# <Axes: xlabel='count', ylabel='Country'>

# %%
sns.countplot(df['Description'])
# Out:
# <Axes: xlabel='count', ylabel='Description'>

# %%
sns.countplot(df['Founded'])
# Out:
# <Axes: ylabel='count'>

# %%
df.Country
# Out:
# 0                Papua New Guinea
# 1                         Finland
# 2                           China
# 3                    Turkmenistan
# 4                       Mauritius
#                  ...
# 95                       Ethiopia
# 96                       Anguilla
# 97    Falkland Islands (Malvinas)
# 98                Kyrgyz Republic
# 99                           Togo
# Name: Country, Length: 100, dtype: str

# %%
sns.boxenplot(df['Country'])
# Out:
# <Axes: ylabel='Country'>

# %%
sns.catplot(df['Description'])

# %%
sns.barplot(df['Index'])
# Out:
# <Axes: ylabel='Index'>

# %%
sns.scatterplot(df['Number of employees'])
# Out:
# <Axes: ylabel='Number of employees'>

# %%
df['Industry'].value_counts().plot(kind = 'area')
# Out:
# <Axes: xlabel='Industry'>

# %%
df.info
# Out:
# <bound method DataFrame.info of     Index  Organization Id                     Name  \
# 0       1  FAB0d41d5b5d22c              Ferrell LLC
# 1       2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1               Hester Ltd
# 3       4  2bFC1Be8a4ce42f           Holder-Sellers
# 4       5  9eE8A6a4Eb96C24              Mayer Group
# ..    ...              ...                      ...
# 95     96  0a0bfFbBbB8eC7c             Holmes Group
# 96     97  BA6Cd9Dae2Efd62                 Good Ltd
# 97     98  E7df80C60Abd7f9        Clements-Espinoza
# 98     99  AFc285dbE2fEd24               Mendez Inc
# 99    100  e9eB5A60Cef8354           Watkins-Kaiser
#
#                            Website                      Country  \
# 0               https://price.net/             Papua New Guinea
# 1   http://www.hall-buchanan.info/                      Finland
# 2        http://sullivan-reed.com/                        China
# ...
